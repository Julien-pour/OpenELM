# %% [markdown]
# # copy logs to run_saved first

# %%
import shutil
import os

# seed=1
# # Paths from which to copy files
# paths_to_copy_seed_s1 = {
#     "/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat,qd=mapelites_rd/23-11-05_22:48/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/random_gen/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=P3ProbSolChatEnv_ELM,qd=cvtmapelites/23-11-05_22:46/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/elm/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=P3ProbSolChatEnv_ELM_NLP/23-11-06_10:17/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/elm_nlp/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_random/23-11-05_23:42/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_random/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_smart/23-11-05_22:48/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_smart/seed{seed}/step_499",
# }

# seed=2
# paths_to_copy_seed_s2 = {
#     "/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat,qd=mapelites_rd/23-11-06_19:36/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/random_gen/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=P3ProbSolChatEnv_ELM,qd=cvtmapelites/23-11-06_19:37/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/elm/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=P3ProbSolChatEnv_ELM_NLP/23-11-06_19:37/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/elm_nlp/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_random/23-11-06_19:34/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_random/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_smart/23-11-06_19:35/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_smart/seed{seed}/step_499",
# }

# seed=3
# paths_to_copy_seed_s3 = {
#     "/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat,qd=mapelites_rd/23-11-07_23:28/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/random_gen/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=P3ProbSolChatEnv_ELM,qd=cvtmapelites/23-11-07_23:26/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/elm/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=P3ProbSolChatEnv_ELM_NLP/23-11-07_23:28/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/elm_nlp/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_random/23-11-07_23:31/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_random/seed{seed}/step_499",
#     "/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_smart/23-11-07_23:30/step_499": f"/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_smart/seed{seed}/step_499",
# }
# # Function to copy files from one directory to another
# def copy_files(source, destination):
#     if not os.path.exists(destination):
#         os.makedirs(destination)
#     if os.path.isdir(source):
#         # If source is a directory, copy the directory
#         shutil.copytree(source, destination, dirs_exist_ok=True)
#     else:
#         # If source is a file, copy the file
#         shutil.copy(source, destination)

# # Copying the files and directories to the new location
# for src, dst in paths_to_copy_seed_s3.items():
#     copy_files(src, dst)

# "Files have been copied to the new paths."
# Out:
# 'Files have been copied to the new paths.'

# %%
# run lae
import shutil
import os

seed=3
# Paths from which to copy files
paths_to_copy_seed_s = {
    f"/media/data/flowers/OpenELM/logs/elm/run_lae/last_steps/env=p3_probsol_Chat,qd=mapelites_rd/seed4{str(1+seed)}/step_499": f"/media/data/flowers/OpenELM/run_saved/full_trainset/random_gen/seed{seed}/step_499",
    f"/media/data/flowers/OpenELM/logs/elm/run_lae/last_steps/env=P3ProbSolChatEnv_ELM,qd=cvtmapelites/seed4{str(1+seed)}/step_499": f"/media/data/flowers/OpenELM/run_saved/full_trainset/elm/seed{seed}/step_499",
    f"/media/data/flowers/OpenELM/logs/elm/run_lae/last_steps/env=P3ProbSolChatEnv_ELM_NLP/seed4{str(1+seed)}/step_499" : f"/media/data/flowers/OpenELM/run_saved/full_trainset/elm_nlp/seed{seed}/step_499",
    f"/media/data/flowers/OpenELM/logs/elm/run_lae/last_steps/env=p3_probsol_Chat_IMGEP_random/seed4{str(1+seed)}/step_499": f"/media/data/flowers/OpenELM/run_saved/full_trainset/imgep_random/seed{seed}/step_499",
    f"/media/data/flowers/OpenELM/logs/elm/run_lae/last_steps/env=p3_probsol_Chat_IMGEP_smart/seed4{str(1+seed)}/step_499": f"/media/data/flowers/OpenELM/run_saved/full_trainset/imgep_smart/seed{seed}/step_499",
}

# Function to copy files from one directory to another
def copy_files(source, destination):
    if not os.path.exists(destination):
        os.makedirs(destination)
    if os.path.isdir(source):
        # If source is a directory, copy the directory
        shutil.copytree(source, destination, dirs_exist_ok=True)
    else:
        # If source is a file, copy the file
        shutil.copy(source, destination)

# Copying the files and directories to the new location
for src, dst in paths_to_copy_seed_s.items():
    copy_files(src, dst)

"Files have been copied to the new paths."
# Out:
# 'Files have been copied to the new paths.'

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import sys
# the mock-0.3.1 dir contains testcase.py, testutils.py & mock.py
sys.path.append('/media/data/flowers/OpenELM')
from utils import *




# rd_gen="/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat,qd=mapelites_rd/23-11-05_22:48/step_499/"
# elm="/media/data/flowers/OpenELM/run_saved/elm/seed1/step_1499/"
# path_centroids= "/media/data/flowers/OpenELM/run_saved/elm/seed1/step_1499/centroids.npy"
# elm_NLP="/media/data/flowers/OpenELM/logs/elm/env=P3ProbSolChatEnv_ELM_NLP/23-11-06_10:17/step_499/"
# imgep_random="/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_random/23-11-05_23:42/step_499/"
# imgep_smart="/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_smart/23-11-05_22:48/step_499/"
list_all_path_seed=[]
for seed in [1,2,3]:
    rd_gen=f"/media/data/flowers/OpenELM/run_saved/limited_trainset/random_gen/seed{seed}/step_499/"
    elm=f"/media/data/flowers/OpenELM/run_saved/limited_trainset/elm/seed{seed}/step_499/"
    path_centroids= "/media/data/flowers/OpenELM/run_saved/elm/seed1/step_1499/centroids.npy"
    elm_NLP=f"/media/data/flowers/OpenELM/run_saved/limited_trainset/elm_nlp/seed{seed}/step_499/"
    imgep_random=f"/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_random/seed{seed}/step_499/"
    imgep_smart=f"/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_smart/seed{seed}/step_499/"

    full_list_path_seed1=[rd_gen,elm,elm_NLP,imgep_random,imgep_smart]
    list_all_path_seed.append(full_list_path_seed1)

list_legend = ["random-gen","ELM","ELM-NLP","IMGEP random", "IMGEP smart"]
#,full_list_path_seed2,full_list_path_seed3]

# %%
list_all_path_seed
# Out:
# [['/media/data/flowers/OpenELM/run_saved/limited_trainset/random_gen/seed1/step_499/',
#   '/media/data/flowers/OpenELM/run_saved/limited_trainset/elm/seed1/step_499/',
#   '/media/data/flowers/OpenELM/run_saved/limited_trainset/elm_nlp/seed1/step_499/',
#   '/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_random/seed1/step_499/',
#   '/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_smart/seed1/step_499/'],
#  ['/media/data/flowers/OpenELM/run_saved/limited_trainset/random_gen/seed2/step_499/',
#   '/media/data/flowers/OpenELM/run_saved/limited_trainset/elm/seed2/step_499/',
#   '/media/data/flowers/OpenELM/run_saved/limited_trainset/elm_nlp/seed2/step_499/',
#   '/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_random/seed2/step_499/',
#   '/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_smart/seed2/step_499/'],
#  ['/media/data/flowers/OpenELM/run_saved/limited_trainset/random_gen/seed3/step_499/',
# ...

# %% [markdown]
# # test fraction of valid generated puzzles

# %%
# num_gen=18
# path_elm="/media/data/flowers/OpenELM/logs/elm/env=P3ProbSolChatEnv_ELM,qd=cvtmapelites/23-11-05_16:51/step_"+str(num_gen)+"/save_all.json"#
# # path_imgep_v0="/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_random/23-11-05_17:04/step_10/save_all.json"
# path_imgep="/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_smart/23-11-05_21:05/step_"+str(num_gen)+"/save_all.json"
# path_imgep_2="/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_smart/23-11-05_22:07/step_"+str(num_gen)+"/save_all.json"
# list_path=[path_elm,path_imgep,path_imgep_2]
# total_puzz=10*3*(num_gen+1)
# for idx_path,path in enumerate(list_path):
#     try:
#         with open(path, 'r') as f:
#             data = json.load(f)
#     except:
#         continue
#     if idx_path==0:
#         print("ELM")
#     if idx_path==1:
#         print("\nIMGEP")
#     if idx_path==2:
#         print("\nIMGEP V_last?")
#     list=[]
#     count_valid=0
#     count_bool_in_invalid=0
#     count_invalid=0
#     for dat in data:
#         if dat["fitness"]==-np.inf:
#             count_invalid+=1
#             # print("\n================")
#             # print(dat["program_str"])
#             try:
#                 out_type=(dat["program_str"].split("->")[1]).split(":")[0]
#             except:
#                 out_type="unk"
#             list.append(out_type)
#             if "bool" in out_type:
#                 count_bool_in_invalid+=1
#         else:
#             count_valid+=1
#     print(f"correct {count_valid}, count_invalid {count_invalid}, count_bool_in_invalid {count_bool_in_invalid}")

#     print(f"valid puzz {(count_valid)/total_puzz*100} % ")
#     print()

# %%
# num_gen=13
# path_imgep="/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_smart/23-11-05_22:07/step_"+str(num_gen)+"/save_all.json"
# with open(path_imgep, 'r') as f:
#     data = json.load(f)
#     if idx_path==0:
#         print("ELM")
#     else:
#         print("\nIMGEP")
# list=[]
# count_valid=0
# count_bool_in_invalid=0
# count_invalid=0
# for dat in data:
#     if dat["fitness"]==-np.inf:
        
#         count_invalid+=1
#         print("\n================")
#         print(dat["program_str"])
#         try:
#             out_type=(dat["program_str"].split("->")[1]).split(":")[0]
#         except:
#             out_type="unk"
#         list.append(out_type)
#         if "bool" in out_type:
#             count_bool_in_invalid+=1
#     else:
#         count_valid+=1

# %% [markdown]
# # number of niches filled

# %%
320*0.65
# Out:
# 208.0

# %%
full_list_niche=[[] for _ in range(len(full_list_path_seed1))]

include_trainset=True
for path_seed_i in list_all_path_seed:
    for idx,baseline in enumerate(path_seed_i):
        try:
            number_of_cells_filled_baseline=return_cells_filled_per_puz_gen_map_elite(baseline,include_full_trainset=include_trainset)#,max_gen=300)
            number_of_cells_filled_baseline=np.array(number_of_cells_filled_baseline)/1024*100

            plt.plot(number_of_cells_filled_baseline,label=list_legend[idx])
            full_list_niche[idx].append(number_of_cells_filled_baseline)
        except:
            pass
    plt.ylabel("fraction of niches filled %")
    plt.xlabel("Number of puzzles generated (sort by generation)")
    plt.legend()
    plt.title("Number of niches filled by puzzles generated \n in a Natural Language Embedding space\n")
    plt.show()

avg_seed_on=False

if avg_seed_on:
    for idx in range(5): 
        liste_len=[len(full_list_niche[idx][i]) for i in range(len(full_list_niche[idx]))]
        min_idx = min(liste_len)
        niches_baseline=np.array(full_list_niche[idx][0][:min_idx])
        for n_seed in range(1,len(full_list_niche[idx])):
            niches_baseline=np.vstack((niches_baseline,full_list_niche[idx][n_seed][:min_idx]))
        means = np.mean(niches_baseline, axis=0)
        std_dev = np.std(niches_baseline, axis=0)

        # Create an x-axis range based on the length of one of the inner lists
        x = range((min_idx))

        # Plot the means with error bars representing the standard deviation
        line, = plt.plot(x,means, label=list_legend[idx])

        # Get the color of the mean line
        line_color = line.get_color()
        plt.fill_between(x,means - std_dev, means + std_dev, color=line_color, alpha=0.1)

    plt.ylabel("fraction of niches filled (%)")
    plt.xlabel("Number of puzzles generated (sort by generation)")
    plt.legend()
    plt.title("Number of niches filled by puzzles generated \n in a Natural Language Embedding space\n")
# Out:
# 7987
# 9693
# 10059
# 4716
# 6718
# 7927
# 9557
# 9946
# 5589
# 6584
# 8088
# 8842
# 10670
# 5483
# 6862

# %%
frac =True

full_list_niche=[[] for _ in range(len(full_list_path_seed1))]


idx_max=500
idx=[i for i in range(idx_max)]
for seed in list_all_path_seed:
    for idx_b,path_map in enumerate(seed):
        with open(path_map+"/maps.pkl", "rb") as f:
            maps = pickle.load(f)
        all_item=getallitems(maps)
        list_gen=[puzz.idx_generation for puzz in all_item] 
        count_item_gen=[list_gen.count(i) for i in range(idx_max)]
        evolution_numb_puzz = np.cumsum(count_item_gen)
        full_list_niche[idx_b].append(evolution_numb_puzz)
        plt.plot(idx,evolution_numb_puzz,alpha=0.6)
    plt.legend(list_legend)
    plt.xlabel("idx of generation")
    plt.ylabel("Number of correct puzzle generated")
    plt.title('evolution of the number of correct puzzle generated ')
    plt.show()
    
    
avg_seed_on=False

if avg_seed_on:
    for idx in range(5): 
        liste_len=[len(full_list_niche[idx][i]) for i in range(len(full_list_niche[idx]))]
        min_idx = min(liste_len)
        niches_baseline=np.array(full_list_niche[idx][0][:min_idx])
        for n_seed in range(1,len(full_list_niche[idx])):
            niches_baseline=np.vstack((niches_baseline,full_list_niche[idx][n_seed][:min_idx]))
        means = np.mean(niches_baseline, axis=0)
        std_dev = np.std(niches_baseline, axis=0)

        # Create an x-axis range based on the length of one of the inner lists
        x = range((min_idx))

        # Plot the means with error bars representing the standard deviation
        line, = plt.plot(x,means, label=list_legend[idx])

        # Get the color of the mean line
        line_color = line.get_color()
        plt.fill_between(x,means - std_dev, means + std_dev, color=line_color, alpha=0.2)

    plt.xlabel("idx of generation")
    plt.ylabel("Number of Correctly Generated Puzzles")
    # plt.title('evolution of the number of correct puzzle generated ')
    plt.legend()
    # plt.savefig("/media/data/flowers/OpenELM/last_fig/number_correct_puzzles_gen.pdf")

# %%
import copy
full_list_niche_=copy.deepcopy(full_list_niche)
for idx in range(5): 
    liste_len=[len(full_list_niche_[idx][i]) for i in range(len(full_list_niche_[idx]))]
    min_idx = min(liste_len)
    niches_baseline=np.array(full_list_niche_[idx][0][:min_idx])
    # for n_seed in range(1,len(full_list_niche_[idx])):
        # niches_baseline=np.vstack((niches_baseline,full_list_niche_[idx][n_seed][:min_idx]))
    max_correct_puzz=np.array([i*10*3 for i in range(1,len(niches_baseline)+1)])
    niches_baseline=niches_baseline/max_correct_puzz*100    
    means =niches_baseline #np.mean(niches_baseline, axis=0)
    # std_dev = np.std(niches_baseline, axis=0)

    # Create an x-axis range based on the length of one of the inner lists
    x = range((min_idx))

    # Plot the means with error bars representing the standard deviation
    line, = plt.plot(x,means, label=list_legend[idx])

    # Get the color of the mean line
    # line_color = line.get_color()
    # plt.fill_between(x,means - std_dev, means + std_dev, color=line_color, alpha=0.2)

plt.xlabel("idx of generation")
plt.ylabel("fraction of valid puzzle generated (%)")
# plt.title('fraction of valid puzzle generated over generation')

plt.legend()
# plt.savefig("/media/data/flowers/OpenELM/last_fig/fraction_correct_puzzles_gen.pdf")

# %% [markdown]
# # test target

# %%
full_list_path_seed1
# Out:
# ['/media/data/flowers/OpenELM/run_saved/limited_trainset/random_gen/seed2/step_499/',
#  '/media/data/flowers/OpenELM/run_saved/limited_trainset/elm/seed2/step_499/',
#  '/media/data/flowers/OpenELM/run_saved/limited_trainset/elm_nlp/seed2/step_499/',
#  '/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_random/seed2/step_499/',
#  '/media/data/flowers/OpenELM/run_saved/limited_trainset/imgep_smart/seed2/step_499/']

# %%
import pickle
seed=2
path_rd=list_all_path_seed[seed][3]#"/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_random/23-10-26_15:35/step_25"
path_smart=list_all_path_seed[seed][4]#"/media/data/flowers/OpenELM/logs/elm/env=p3_probsol_Chat_IMGEP_smart/23-10-26_15:39/step_25"
list_path=[path_rd,path_smart]
list_results=[]
list_unique_niche=[]
for path in list_path:
    with open(path+"/maps.pkl", 'rb') as f:
        maps = pickle.load(f)
    list_items=getallitems(maps)
    archive = [i.__dict__ for i in list_items if i.idx_generation!=-1] 
    full_archive = [i.__dict__ for i in list_items]
    sorted_archive = sorted(archive, key=lambda x: x["idx_generation"])
    list_emb =np.array([item["emb"] for item in sorted_archive])
    list_emb_str =([str(item["emb"]) for item in sorted_archive])
    list_emb_str_full =([str(item["emb"]) for item in full_archive])

    print(f"unique niches without trainset/total puzzle gen= {len(set(list_emb_str))}/ {len(list_emb_str)}",)
    print(f"unique niches with trainset/total puzzle gen= {len(set(list_emb_str_full))}/ {len(list_emb_str)}",)

    print("")
    list_idx_generation= np.array([item["idx_generation"] for item in sorted_archive])
    
    # for idx_gen in tqdm(list_gen_2compute):
    #     idx_cond_i=list_idx_generation <= idx_gen
    #     idx_last=len(list_idx_generation[idx_cond_i])
    #     # sorted_archive[:idx_last]
        
        
    list_emb=np.array([puzzle["emb"] for puzzle in sorted_archive])
    list_target = np.array([puzzle["target_skills"] for puzzle in sorted_archive])
    list_results.append(np.count_nonzero(list_emb!=list_target,axis=1))
plt.hist(list_results,label=["IMGEP rd","IMGEP smart"])
plt.legend()
plt.xlabel("hamming distance")
plt.ylabel("count")
plt.title("Hamming distance between target and generated puzzles")
plt.show()
# Out:
# unique niches without trainset/total puzzle gen= 306/ 5483
# unique niches with trainset/total puzzle gen= 306/ 5483
#
# unique niches without trainset/total puzzle gen= 586/ 6862
# unique niches with trainset/total puzzle gen= 586/ 6862

# %%
bs=1
list_gen_2compute = [i for i in range(0,400,bs)]
all_res=[]
list_results=[]
for path in list_path:
    with open(path+"/maps.pkl", 'rb') as f:
        maps = pickle.load(f)
    list_items=getallitems(maps)
    archive = [i.__dict__ for i in list_items if i.idx_generation!=-1] 
    sorted_archive = sorted(archive, key=lambda x: x["idx_generation"])
    
    list_idx_generation= np.array([item["idx_generation"] for item in sorted_archive])
    list_emb =np.array([item["emb"] for item in sorted_archive])
    list_target = np.array([puzzle["target_skills"] for puzzle in sorted_archive])
    list_results.append(np.count_nonzero(list_emb!=list_target,axis=1))
list_plot_seed_i=[]  
for idx_gen in (list_gen_2compute):
    idx_cond_i=list_idx_generation <= idx_gen
    idx_last=len(list_idx_generation[idx_cond_i])
    list_results_i=[res_i[:idx_last].mean() for res_i in list_results]  
    list_plot_seed_i.append(list_results_i)
    
plt.plot(list_gen_2compute,list_plot_seed_i)
plt.legend(["IMGEP rd","IMGEP smart"])
plt.title("Hamming distance between target and generated puzzles")

plt.xlabel("idx of generation")
plt.ylabel("mean hamming distance")
all_res.append([list_plot_seed_i])
    
# plt.hist(list_results,label=["IMGEP rd","IMGEP smart"])
# plt.legend()
    # plt.xlabel("hamming distance")
    # plt.ylabel("count")
    # plt.show()

# %%
bs=100
list_gen_2compute = [i for i in range(0,1501,bs)]

for all_path_all_emb in list_all_path_seed:
    list_results=[]
    for idx,path_puzzles in enumerate(all_path_all_emb[-2:]):
        with open(path_puzzles) as f:
            archive=json.load(f)
        sorted_archive = sorted(archive, key=lambda x: x["idx_generation"])
        list_emb =np.array([item["emb"] for item in sorted_archive])
        list_idx_generation= np.array([item["idx_generation"] for item in sorted_archive])
        
        # for idx_gen in tqdm(list_gen_2compute):
        #     idx_cond_i=list_idx_generation <= idx_gen
        #     idx_last=len(list_idx_generation[idx_cond_i])
        #     # sorted_archive[:idx_last]
            
            
        list_emb=np.array([puzzle["emb"] for puzzle in sorted_archive])
        list_target = np.array([puzzle["target_skills"] for puzzle in sorted_archive])
        list_results.append(np.count_nonzero(list_emb!=list_target,axis=1))
    plt.hist(list_results,label=["IMGEP rd","IMGEP smart"])
    plt.legend()
    plt.xlabel("hamming distance")
    plt.ylabel("count")
    plt.title("Hamming distance between target and generated puzzles")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[17], line 7
#       5 list_results=[]
#       6 for idx,path_puzzles in enumerate(all_path_all_emb[-2:]):
# ----> 7     with open(path_puzzles) as f:
#       8         archive=json.load(f)
#       9     sorted_archive = sorted(archive, key=lambda x: x["idx_generation"])
#
# File /media/data/flowers/conda/envs/codegpt/lib/python3.10/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# ...
